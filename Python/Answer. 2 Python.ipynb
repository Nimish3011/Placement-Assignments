# %% [markdown]
# ### 💡 **Question 2:** -
#
# Consider a string to be valid if all characters of the string appear the same number of times. It is also valid if
# he can remove just one character at the index in the string, and the remaining characters will occur the same
# number of times. Given a string, determine if it is valid. If so, return YES , otherwise return NO.
#
# **Note**- You have to write at least 2 additional test cases in which your program will run successfully and provide
# an explanation for the same.
#
# **Example** input 1 - s = “abc”. This is a valid string because frequencies are { “a”: 1, “b”: 1, “c”: 1 }
#
# **Example** output 1- YES
#
# **Example** input 2 - s “abcc”. This string is not valid as we can remove only 1 occurrence of “c”. That leaves
#
# character frequencies of { “a”: 1, “b”: 1 , “c”: 2 }
#
# **Example** output 2 - NO

# %%
from collections import Counter

def is_valid_string(s):
    char_counts = Counter(s)
    counts = set(char_counts.values())

    if len(counts) == 1:
        return "YES"
    elif len(counts) > 2:
        return "NO"
    elif 1 in counts and list(counts).count(1) == 1:
        return "YES"
    else:
        return "NO"

# %%
test_cases = [
  ("abc", "YES"),
  ("a", "YES")
]

for input_string, expected_output in test_cases:
  actual_output = is_valid_string(input_string)
  if actual_output == expected_output:
    print("Test case passed.")
  else:
    print(f"Test case failed. Input: {input_string}, Expected: {expected_output}, Actual: {actual_output}")
# Out:
# Test case passed.
# Test case passed.

# %% [markdown]
# **Test case 1:**
#
# string = "abc"
#
# expected_output = True
#
# explanation:
#
# The string "abc" has all characters occurring the same number of times (once). Therefore, the string is valid.

# %% [markdown]
# **Test case 2:**
#
# string = "a"
#
# expected_output = True
#
# explanation:
#
# The string "a" has all characters occurring the same number of times (once). Therefore, the string is valid.
